# %% [markdown]
# # DEMO: Integrating Azure Event Hubs and Azure Databricks
# ---
# Author: Max Fisher
#
# ---
# In this demo we will establish our real-time stream of data using the Python client provided by the lab files. This real-time stream will go through Azure Event Hubs, which is a popular tool for managing incoming messages and data to Azure. From Event Hubs, we will be demonstrating how to set up the connection between Event Hub and your structured streaming pipeline.
#
# First, let's provision Azure Event Hubs. Come back to this notebook once you have this provisioned.
#
# Secondly, let's take a quick look at the code in the Python Producer. It will be called `sender.py` in the Demo folder.
#
# Lastly, enter in the credentials for the Azure Event Hub into the `sender.py` and run the Python Program.
#
# Now we have data flowing from our Python Producer to Azure Event Hubs. The next step is to set up the connection to Azure Databricks and our structured streaming pipeline.

# %%
# The connection string to your Event Hubs Namespace
connectionString = "<connection-string>;EntityPath=<hub-name>"
# Event Hubs Connection Configuration
ehConf = {
  'eventhubs.connectionString' : connectionString
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# The next step is to set up the `readStream` event. For this stream we are not going to use any triggers or windows just so we can focus on the Event Hubs functionality.
#
# Within this `readStream` object we have a `format` element that is used to specify the format of the message that is being read in. **"org.apache.spark.sql.eventhubs.EventHubsSourceProvider"** is the format type you need to specify for messages coming from Azure Event Hubs.
#
# The next option uses the `options` to reference the **ehConf** object, which we defined in the earlier cell. This is the configuration details for the connection to the hub you are streaming from. **Note**: Make sure you append **";EntityPath=hub-name"** to the end of the namespace's connection string or the connection will not be correct.

# %%
productsSoldStream = spark \
  .readStream \
  .format("org.apache.spark.sql.eventhubs.EventHubsSourceProvider") \
  .options(**ehConf) \
  .load()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(productsSoldStream)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>body</th><th>offset</th><th>sequenceNumber</th><th>enqueuedTime</th><th>publisher</th><th>partitionKey</th></tr></thead><tbody><tr><td>eyJzdG9yZUlkIjogMTAwNCwgInRpbWVzdGFtcCI6IDE1NDE2OTQyMTAuNDY5NDE0LCAicHJvZHVjdHR5cGUiOiA3LCAibmFtZSI6ICJCbGVuZGVyIiwgImNhdGVnb3J5IjogIktpdGNoZW4iLCAicHJpY2UiOiAyNS45OSwgInF1YW50aXR5IjogM30=</td><td>6384160</td><td>29464</td><td>2018-11-08T16:23:19.340+0000</td><td>null</td><td>null</td></tr><tr><td>eyJzdG9yZUlkIjogMTAwNCwgInRpbWVzdGFtcCI6IDE1NDE2OTQyMTUuNTQzNTM2LCAicHJvZHVjdHR5cGUiOiAxMCwgIm5hbWUiOiAiQ3V0dGluZyBCb2FyZCIsICJjYXRlZ29yeSI6ICJLaXRjaGVuIiwgInByaWNlIjogMTIuOTksICJxdWFudGl0eSI6IDN9</td><td>6569264</td><td>30300</td><td>2018-11-08T16:23:24.430+0000</td><td>null</td><td>null</td></tr><tr><td>eyJzdG9yZUlkIjogMTAwMSwgInRpbWVzdGFtcCI6IDE1NDE2OTQyMjAuNjE5NTk2MiwgInByb2R1Y3R0eXBlIjogOSwgIm5hbWUiOiAiUmljZSBDb29rZXIiLCAiY2F0ZWdvcnkiOiAiS2l0Y2hlbiIsICJwcmljZSI6IDI5Ljk5LCAicXVhbnRpdHkiOiAyfQ==</td><td>6384352</td><td>29465</td><td>2018-11-08T16:23:29.484+0000</td><td>null</td><td>null</td></tr><tr><td>eyJzdG9yZUlkIjogMTA
0000</td><td>null</td><td>null</td></tr><tr><td>eyJzdG9yZUlkIjogMTAwMywgInRpbWVzdGFtcCI6IDE1NDE2OTQyNjEuMzIyNzY5LCAicHJvZHVjdHR5cGUiOiAzLCAibmFtZSI6ICJXb29kZW4gU3Bvb24iLCAiY2F0ZWdvcnkiOiAiS2l0Y2hlbiIsICJwcmljZSI6IDEuOTksICJxdWFudGl0eSI6IDF9</td><td>6385144</td><td>29469</td><td>2018-11-08T16:24:10.205+0000</td><td>null</td><td>null</td></tr><tr><td>eyJzdG9yZUlkIjogMTAwNCwgInRpbWVzdGFtcCI6IDE1NDE2OTQyNjYuNDM5NzM0NSwgInByb2R1Y3R0eXBlIjogMiwgIm5hbWUiOiAiU3BhdHVsYSIsICJjYXRlZ29yeSI6ICJLaXRjaGVuIiwgInByaWNlIjogMi45OSwgInF1YW50aXR5IjogMn0=</td><td>6570248</td><td>30305</td><td>2018-11-08T16:24:15.325+0000</td><td>null</td><td>null</td></tr><tr><td>eyJzdG9yZUlkIjogMTAwMCwgInRpbWVzdGFtcCI6IDE1NDE2OTQyNzEuNTQ5Mzk1NiwgInByb2R1Y3R0eXBlIjogMTAsICJuYW ...

# %% [markdown]
# Here we are defining the query that will be run on the events that are streaming into Azure Databricks. We first need to cast the message as a string becuase the content of the message is stored as binary in the body field of the productsSoldStream DataFrame. This casting is done within the `select` function which is selecting all of the content that is being streamed in the body.
#
# Another piece you might notice is that we use `alias` to cast the column the data is being written to as **message**.

# %%
IncrementalQuery = productsSoldStream.select(productsSoldStream.body.cast("string").alias('message'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# We can take a quick look at how the data will be written by using the `display()` function for the dataframe.

# %%
display(IncrementalQuery)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>message</th></tr></thead><tbody><tr><td>{"storeId": 1004, "timestamp": 1541694190.0443802, "producttype": 10, "name": "Cutting Board", "category": "Kitchen", "price": 12.99, "quantity": 2}</td></tr><tr><td>{"storeId": 1000, "timestamp": 1541694184.965651, "producttype": 6, "name": "Saucepan", "category": "Kitchen", "price": 21.99, "quantity": 3}</td></tr><tr><td>{"storeId": 1008, "timestamp": 1541694195.120094, "producttype": 6, "name": "Saucepan", "category": "Kitchen", "price": 21.99, "quantity": 1}</td></tr><tr><td>{"storeId": 1006, "timestamp": 1541694200.2508397, "producttype": 5, "name": "Roasting Pan", "category": "Kitchen", "price": 17.99, "quantity": 1}</td></tr><tr><td>{"storeId": 1009, "timestamp": 1541694205.3889291, "producttype": 1, "name": "Chef's Knife", "category": "Kitchen", "price": 15.99, "quantity": 1}</td></tr><tr><td>{"storeId": 1004, "timestamp": 1541694210.469414, "producttype": 7, "name": "Blender", "category": "Kitchen", "price": 25.99, "quantity": 3}</td></tr><tr><td>{"storeId": 1004, "timestamp": 1541694215.543536, "producttype": 10, "name": "Cutting Board", "category": "Kitchen", "price": 12.99, "quantity": 3}</td></tr><tr><td>{"storeId": 1001, "timestamp": 1541694220.6195962, "producttype": 9, "name": "Rice Cooker", "category": "Kitchen", "price": 29.99, "quantity": 2}</td></tr><tr><td>{"storeId": 1004, "timestamp": 1541694225.7162404, "producttype": 10, "name": "Cutting Board", "category": "Kitchen", "price": 12.99, "quantity": 3}</td></tr><tr><td>{"storeId": 1005, "timestamp": 1541694230.8098633, "producttype": 9, "name": "Rice Cooker", "category": "Kitchen", "price": 29.99, "quantity": 1}</td></tr><tr><td>{"storeId": 1003, "timestamp": 1541694235.9129448, "producttype": 7, "name": "Blender", "category": "Kitchen", "price": 25.99, "quantity": 2}</td></tr><tr><td>{"storeId": 1007, "timestamp": 1541694240.990411, "producttype": 10, "name": "Cutting Board", "category": "Kitchen", "price": 12.99, "quantity": 1}</td></tr><tr><td>{"storeId": 1008, "timestamp": 1541694246.062125, "producttype": 2, "name": "Spatula", "category": "Kitchen", "price": 2.99, "quantity": 2}</td></tr><tr><td>{"storeId": 1009, "timestamp": 1541694251.1375847, "producttype": 7, "name": "Blender", "category": "Kitchen", "price": 25.99, "quantity": 1}</td></tr><tr><td>{"storeId": 1004, "timestamp": 1541694256.2139943, "producttype": 10, "name": "Cutting Board", "category": "Kitchen", "price": 12.99, "quantity": 3}</td></tr><tr><td>{"storeId": 1003, "timestamp": 1541694261.322769, "producttype": 3, "name": "Wooden Spoon", "category": "Kitchen", "price": 1.99, "quantity": 1}</td></tr><tr><td>{"storeId": 1004, "timestamp": 1541694266.4397345, "producttype": 2, "name": "Spatula", "category": "Kitchen", "price": 2.99, "quantity": 2}</td></tr><tr><td>{"storeId": 1000, "timestamp": 1541694271.5493956, "producttype": 10, "name": "Cutting Board", "category": "Kitchen", "price": 12.99, "quantity": 1}</td></tr><tr><td>{"storeId": 1000, "timestamp": 1541694276.6435885, "producttype": 4, "name": "Knife Block", "category": "Kitchen", "price": 10.99, "quantity": 3}</td></tr><tr><td>{"storeId": 1004, "timestamp": 1541694281.7961292, "producttype": 9, "name": "Rice Cooker", "category": "Kitchen", "price": 29.99, "quantity": 1}</td></tr><tr><td>{"storeId": 1002, "timestamp": 1541694286.8688035, "producttype": 7, "name": "Blender", "category": "Kitchen", "price": 25.99, "quantity": 1}</td></tr><tr><td>{"storeId": 1002, "timestamp": 1541694291.9408412, "producttype": 9, "name": "Rice Cooker", "category": "Kitchen", "price": 29.99, "quantity": 2}</td></tr><tr><td>{"storeId": 1008, "timestamp": 1541694297.014398, "producttype": 7, "name": "Blender", "category": "Kitchen", "price": 25.99, "quantity": 2}</td></tr><tr><td>{"storeId": 1009, "timestamp": 1541694302.0881298, "producttype": 1, "name": "Chef's Knife", "category": "Kitchen",  ...

# %% [markdown]
# Now that we have reviewed what the data will look like, let's actually write the data to our desired folder using the `writeStream` event.

# %%
IncrementalQuery.writeStream \
          .outputMode("append") \
          .format("json") \
          .option("path", "/wwComDemo/data") \
          .option("checkpointLocation", "wwComDemo/checkpoints") \
          .start()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">16</span><span class="ansired">]: </span>&lt;pyspark.sql.streaming.StreamingQuery at 0x7fbb5a7fe208&gt;
# </div>

# %% [markdown]
# Now let's check to see if a file has been written using `dbutils`

# %%
# check to see if the files made it!

if (dbutils.fs.ls("/wwComDemo/data") == []):
  print("There is no data! :(")
else:
  print("The data made it!")
  print(dbutils.fs.ls("/wwComDemo/data")[3])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The data made it!
# FileInfo(path=&apos;dbfs:/wwComDemo/data/part-00000-615f358d-951b-4871-a5da-78470260847b-c000.json&apos;, name=&apos;part-00000-615f358d-951b-4871-a5da-78470260847b-c000.json&apos;, size=179)
# </div>
