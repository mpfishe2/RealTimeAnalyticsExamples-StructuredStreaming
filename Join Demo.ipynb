# %% [markdown]
# # DEMO: Using Reference Data in a Streaming Pipeline
# ---
#
# Author: Max Fisher (mafis)
#
# ---
#
# In this demo we will show how you can incorporate static reference data to enrich incoming, real-time data. Sometimes you will have scenarios where you may need to tag certain messages with a particular identifier, or maybe the refernece data holds some values that you need to check to see whether the incoming data is relevant.
#
# Whatever your case may be, reference data can help us enrich our real-time pipelines, so let us demonstrate how to handle this while using Structured Streaming.
#
# First, let's provision Azure Event Hubs. Come back to this notebook once you have this provisioned.
#
# Secondly, let's take a quick look at the code in the Python Producer. It will be called `sender.py` in the Demo folder.
#
# Lastly, enter in the credentials for the Azure Event Hub into the `sender.py` and run the Python Program.

# %% [markdown]
# First, lets take a look at the reference data itself. We should have it sitting in DBFS, let's check. If you have not imported the stores.csv, please import the CSV into Databricks by dragging and dropping the stores.csv from this Demo's Data folder into the Databricks Workspace. Ensure that the file is saved as a table with the title seen in the filepath below.

# %%
storesDF = spark.read.csv(dbutils.fs.ls("/FileStore/tables/stores.csv")[0][0], header=True, inferSchema=True)
storesDF.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------------+-------------+
# StoreId|StoreLocation|StoreMangerId|
# +-------+-------------+-------------+
#    1000|        10013|            1|
#    1001|        10014|            2|
#    1002|        10015|            3|
#    1003|        10001|            4|
#    1004|        10002|            5|
#    1005|        10004|            6|
#    1006|        10005|            7|
#    1007|        10006|            8|
#    1008|        10007|            9|
#    1009|        10008|           10|
#    1010|        10009|           11|
# +-------+-------------+-------------+
#
# </div>

# %% [markdown]
# Now let's establish our connection to the stream of data in the Azure Event Hub. The following two cells both estblish the connection string, configuration object, and the readStream event.

# %%
# The connection string to your Event Hubs Namespace
connectionString = "<connection-string>;EntityPath=<hub-name>"
# Event Hubs Connection Configuration
ehConf = {
  'eventhubs.connectionString' : connectionString
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
productsSoldStream = spark \
  .readStream \
  .format("org.apache.spark.sql.eventhubs.EventHubsSourceProvider") \
  .options(**ehConf) \
  .load()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(productsSoldStream)

# %% [markdown]
# Now let's import some PySpark libraries so that we can use StructField, StructType, and from_json.

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# In the following cell we both grab the data being streamed into the EventHub and the Arrival Time of the message that Azure provides.

# %%
productsRaw = productsSoldStream.select(productsSoldStream.body.cast('string'), productsSoldStream.enqueuedTime.alias('ArrivalTime'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Now let's take a look at the initial data.

# %%
display(productsRaw)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>body</th><th>ArrivalTime</th></tr></thead><tbody><tr><td>{"storeId": 1007, "timestamp": 1541695193.6862552, "producttype": 9, "name": "Rice Cooker", "category": "Kitchen", "price": 29.99, "quantity": 1}</td><td>2018-11-08T16:39:42.586+0000</td></tr><tr><td>{"storeId": 1005, "timestamp": 1541695198.7693238, "producttype": 1, "name": "Chef's Knife", "category": "Kitchen", "price": 15.99, "quantity": 2}</td><td>2018-11-08T16:39:47.656+0000</td></tr><tr><td>{"storeId": 1001, "timestamp": 1541695506.1699357, "producttype": 3, "name": "Wooden Spoon", "category": "Kitchen", "price": 1.99, "quantity": 3}</td><td>2018-11-08T16:44:55.493+0000</td></tr><tr><td>{"storeId": 1007, "timestamp": 1541695511.715615, "producttype": 6, "name": "Saucepan", "category": "Kitchen", "price": 21.99, "quantity": 3}</td><td>2018-11-08T16:45:00.643+0000</td></tr><tr><td>{"storeId": 1001, "timestamp": 1541695516.8080485, "producttype": 1, "name": "Chef's Knife", "category": "Kitchen", "price": 15.99, "quantity": 3}</td><td>2018-11-08T16:45:05.729+0000</td></tr><tr><td>{"storeId": 1001, "timestamp": 1541695521.9041686, "producttype": 5, "name": "Roasting Pan", "category": "Kitchen", "price": 17.99, "quantity": 3}</td><td>2018-11-08T16:45:10.816+0000</td></tr><tr><td>{"storeId": 1008, "timestamp": 1541695526.9835958, "producttype": 2, "name": "Spatula", "category": "Kitchen", "price": 2.99, "quantity": 1}</td><td>2018-11-08T16:45:15.885+0000</td></tr><tr><td>{"storeId": 1002, "timestamp": 1541695532.0606434, "producttype": 11, "name": "Grill", "category": "Outdoors", "price": 159.99, "quantity": 1}</td><td>2018-11-08T16:45:20.962+0000</td></tr><tr><td>{"storeId": 1006, "timestamp": 1541695537.138222, "producttype": 9, "name": "Rice Cooker", "category": "Kitchen", "price": 29.99, "quantity": 1}</td><td>2018-11-08T16:45:26.027+0000</td></tr><tr><td>{"storeId": 1002, "timestamp": 1541695542.2193782, "producttype": 1, "name": "Chef's Knife", "category": "Kitchen", "price": 15.99, "quantity": 2}</td><td>2018-11-08T16:45:31.150+0000</td></tr><tr><td>{"storeId": 1002, "timestamp": 1541695547.36186, "producttype": 1, "name": "Chef's Knife", "category": "Kitchen", "price": 15.99, "quantity": 1}</td><td>2018-11-08T16:45:36.264+0000</td></tr><tr><td>{"storeId": 1005, "timestamp": 1541695552.438633, "producttype": 9, "name": "Rice Cooker", "category": "Kitchen", "price": 29.99, "quantity": 1}</td><td>2018-11-08T16:45:41.355+0000</td></tr><tr><td>{"storeId": 1006, "timestamp": 1541695557.5297103, "producttype": 7, "name": "Blender", "category": "Kitchen", "price": 25.99, "quantity": 3}</td><td>2018-11-08T16:45:46.421+0000</td></tr><tr><td>{"storeId": 1009, "timestamp": 1541695562.604473, "producttype": 4, "name": "Knife Block", "category": "Kitchen", "price": 10.99, "quantity": 2}</td><td>2018-11-08T16:45:51.512+0000</td></tr><tr><td>{"storeId": 1004, "timestamp": 1541695567.72709, "producttype": 10, "name": "Cutting Board", "category": "Kitchen", "price": 12.99, "quantity": 1}</td><td>2018-11-08T16:45:56.626+0000</td></tr><tr><td>{"storeId": 1007, "timestamp": 1541695572.8029454, "producttype": 8, "name": "Toaster", "category": "Kitchen", "price": 30.99, "quantity": 2}</td><td>2018-11-08T16:46:01.700+0000</td></tr><tr><td>{"storeId": 1006, "timestamp": 1541695577.8798637, "producttype": 2, "name": "Spatula", "category": "Kitchen", "price": 2.99, "quantity": 2}</td><td>2018-11-08T16:46:06.799+0000</td></tr><tr><td>{"storeId": 1003, "timestamp": 1541695582.9763372, "producttype": 4, "name": "Knife Block", "category": "Kitchen", "price": 10.99, "quantity": 1}</td><td>2018-11-08T16:46:11.872+0000</td></tr><tr><td>{"storeId": 1005, "timestamp": 1541695588.0464525, "producttype": 10, "name": "Cutting Board", "category": "Kitchen", "price": 12.99, "quantity": 1}</td><td>2018-11-08T16:46:16.940+0000</td></tr><tr><td>{"storeId": 1005, "timestamp": 1541695593.125 ...

# %% [markdown]
# To use the refernce data we are going to need to break that json stucture apart. The first step is to establish a schema for those fields. We include Arrival Time since we want to bring that field across as well. We use the `from_json` function imported in the `pyspark.sql.functions` library earlier. This function parses the JSON to create a struct object based off the field in the JSON message.

# %%
productsSchema = StructType([
  StructField("storeId", IntegerType(), True),
  StructField("timestamp", StringType(), True),
  StructField("producttype", IntegerType(), True),
  StructField("name", StringType(), True),
  StructField("category", StringType(), True),
  StructField("price", DoubleType(), True),
  StructField("quantity", IntegerType(), True)
])

productsJson = productsRaw.select(from_json(productsRaw.body, schema=productsSchema).alias("json"), productsRaw.ArrivalTime)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Let's take a look at the table that is streamed now.

# %%
display(productsJson)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>json</th><th>ArrivalTime</th></tr></thead><tbody><tr><td>List(1007, 1.5416951936862552E9, 9, Rice Cooker, Kitchen, 29.99, 1)</td><td>2018-11-08T16:39:42.586+0000</td></tr><tr><td>List(1005, 1.5416951987693238E9, 1, Chef's Knife, Kitchen, 15.99, 2)</td><td>2018-11-08T16:39:47.656+0000</td></tr><tr><td>List(1001, 1.5416955061699357E9, 3, Wooden Spoon, Kitchen, 1.99, 3)</td><td>2018-11-08T16:44:55.493+0000</td></tr><tr><td>List(1007, 1.541695511715615E9, 6, Saucepan, Kitchen, 21.99, 3)</td><td>2018-11-08T16:45:00.643+0000</td></tr><tr><td>List(1001, 1.5416955168080485E9, 1, Chef's Knife, Kitchen, 15.99, 3)</td><td>2018-11-08T16:45:05.729+0000</td></tr><tr><td>List(1001, 1.5416955219041686E9, 5, Roasting Pan, Kitchen, 17.99, 3)</td><td>2018-11-08T16:45:10.816+0000</td></tr><tr><td>List(1008, 1.5416955269835958E9, 2, Spatula, Kitchen, 2.99, 1)</td><td>2018-11-08T16:45:15.885+0000</td></tr><tr><td>List(1002, 1.5416955320606434E9, 11, Grill, Outdoors, 159.99, 1)</td><td>2018-11-08T16:45:20.962+0000</td></tr><tr><td>List(1006, 1.541695537138222E9, 9, Rice Cooker, Kitchen, 29.99, 1)</td><td>2018-11-08T16:45:26.027+0000</td></tr><tr><td>List(1002, 1.5416955422193782E9, 1, Chef's Knife, Kitchen, 15.99, 2)</td><td>2018-11-08T16:45:31.150+0000</td></tr><tr><td>List(1002, 1.54169554736186E9, 1, Chef's Knife, Kitchen, 15.99, 1)</td><td>2018-11-08T16:45:36.264+0000</td></tr><tr><td>List(1005, 1.541695552438633E9, 9, Rice Cooker, Kitchen, 29.99, 1)</td><td>2018-11-08T16:45:41.355+0000</td></tr><tr><td>List(1006, 1.5416955575297103E9, 7, Blender, Kitchen, 25.99, 3)</td><td>2018-11-08T16:45:46.421+0000</td></tr><tr><td>List(1009, 1.541695562604473E9, 4, Knife Block, Kitchen, 10.99, 2)</td><td>2018-11-08T16:45:51.512+0000</td></tr><tr><td>List(1004, 1.54169556772709E9, 10, Cutting Board, Kitchen, 12.99, 1)</td><td>2018-11-08T16:45:56.626+0000</td></tr><tr><td>List(1007, 1.5416955728029454E9, 8, Toaster, Kitchen, 30.99, 2)</td><td>2018-11-08T16:46:01.700+0000</td></tr><tr><td>List(1006, 1.5416955778798637E9, 2, Spatula, Kitchen, 2.99, 2)</td><td>2018-11-08T16:46:06.799+0000</td></tr><tr><td>List(1003, 1.5416955829763372E9, 4, Knife Block, Kitchen, 10.99, 1)</td><td>2018-11-08T16:46:11.872+0000</td></tr><tr><td>List(1005, 1.5416955880464525E9, 10, Cutting Board, Kitchen, 12.99, 1)</td><td>2018-11-08T16:46:16.940+0000</td></tr><tr><td>List(1005, 1.5416955931256611E9, 11, Grill, Outdoors, 159.99, 2)</td><td>2018-11-08T16:46:22.029+0000</td></tr><tr><td>List(1000, 1.5416955982023134E9, 5, Roasting Pan, Kitchen, 17.99, 1)</td><td>2018-11-08T16:46:27.112+0000</td></tr><tr><td>List(1003, 1.5416956033202233E9, 6, Saucepan, Kitchen, 21.99, 3)</td><td>2018-11-08T16:46:32.279+0000</td></tr><tr><td>List(1001, 1.5416956084661822E9, 6, Saucepan, Kitchen, 21.99, 1)</td><td>2018-11-08T16:46:37.362+0000</td></tr><tr><td>List(1002, 1.5416956135916412E9, 11, Grill, Outdoors, 159.99, 2)</td><td>2018-11-08T16:46:42.498+0000</td></tr><tr><td>List(1002, 1.5416956186665778E9, 4, Knife Block, Kitchen, 10.99, 1)</td><td>2018-11-08T16:46:47.556+0000</td></tr><tr><td>List(1004, 1.541695623742716E9, 6, Saucepan, Kitchen, 21.99, 2)</td><td>2018-11-08T16:46:52.640+0000</td></tr><tr><td>List(1004, 1.5416956288179677E9, 2, Spatula, Kitchen, 2.99, 2)</td><td>2018-11-08T16:46:57.712+0000</td></tr><tr><td>List(1010, 1.5416956339085925E9, 5, Roasting Pan, Kitchen, 17.99, 1)</td><td>2018-11-08T16:47:02.828+0000</td></tr><tr><td>List(1010, 1.541695639006253E9, 3, Wooden Spoon, Kitchen, 1.99, 1)</td><td>2018-11-08T16:47:07.902+0000</td></tr><tr><td>List(1005, 1.541695644079338E9, 8, Toaster, Kitchen, 30.99, 3)</td><td>2018-11-08T16:47:12.985+0000</td></tr><tr><td>List(1007, 1.541695649147064E9, 8, Toaster, Kitchen, 30.99, 2)</td><td>2018-11-08T16:47:18.043+0000</td></tr><tr><td>List(1007, 1.5416956542300935E9, 4, Knife Block, Kitchen, 10.99, 2)</td><td>2018-11-08T16:47: ...

# %% [markdown]
# Now from this struct object we need to select the relevant fields that we want. In this case we want all the fields in the struct, so we use the asterisk `<field_name>.*` to grab all the fields in the struct. Since the struct has a name of `json` we write `json.*` since `json` is the `<field_name>`.

# %%
products = productsJson.select("json.*", productsJson.ArrivalTime)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Now let's take a look.

# %%
display(products)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>storeId</th><th>timestamp</th><th>producttype</th><th>name</th><th>category</th><th>price</th><th>quantity</th><th>ArrivalTime</th></tr></thead><tbody><tr><td>1007</td><td>1.5416951936862552E9</td><td>9</td><td>Rice Cooker</td><td>Kitchen</td><td>29.99</td><td>1</td><td>2018-11-08T16:39:42.586+0000</td></tr><tr><td>1005</td><td>1.5416951987693238E9</td><td>1</td><td>Chef's Knife</td><td>Kitchen</td><td>15.99</td><td>2</td><td>2018-11-08T16:39:47.656+0000</td></tr><tr><td>1001</td><td>1.5416955061699357E9</td><td>3</td><td>Wooden Spoon</td><td>Kitchen</td><td>1.99</td><td>3</td><td>2018-11-08T16:44:55.493+0000</td></tr><tr><td>1007</td><td>1.541695511715615E9</td><td>6</td><td>Saucepan</td><td>Kitchen</td><td>21.99</td><td>3</td><td>2018-11-08T16:45:00.643+0000</td></tr><tr><td>1001</td><td>1.5416955168080485E9</td><td>1</td><td>Chef's